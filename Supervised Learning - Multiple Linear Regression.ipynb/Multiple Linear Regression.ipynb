# %%
import pandas as pd # For reading and preprocessing data for use in scikit-learn.
import numpy as np # Allows you to work with multidimensional arrays and matrices. It’s perfect for scientific or mathematical calculations.
import matplotlib.pyplot as plt # Essential for Data visualization.
from sklearn.linear_model import LinearRegression # Involves solving a system of linear equations
from sklearn.model_selection import train_test_split
# %matplotlib inline
# Out:
# C:\Users\tailb\AppData\Local\Temp\ipykernel_10488\3121334474.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd # For reading and preprocessing data for use in scikit-learn.

# %%
file_path ="C:/Users/tailb/Downloads/Advertising.csv" # file_path is essential!
data = pd.read_csv(file_path,index_col=0)
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
tv_model.coef_
# Out:
# array([[0.04753664]])

# %% [markdown]
# TV Simple Linear Model

# %%
x = data.iloc[:,0].values # TV
print(x)
y = data.iloc[:,3].values # Sales
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)
# Out:
# [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 199.8 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7
#   53.5 261.3 239.3 102.7 131.1  69.   31.5 139.3 237.4 216.8 199.1 109.8
#   26.8 129.4 213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4
#  213.5 193.2  76.3 110.7  88.3 109.8 134.3  28.6 217.7 250.9 107.4 163.3
#  197.6 184.9 289.7 135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4
#   13.1 255.4 225.8 241.7 175.7 209.6  78.2  75.1 139.2  76.4 125.7  19.4
#  141.3  18.8 224.  123.1 229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2
#    8.4 219.8  36.9  48.3  25.6 273.7  43.  184.9  73.4 193.7 220.5 104.6
#   96.2 140.3 240.1 243.2  38.   44.7 280.7 121.  197.6 171.3 187.8   4.1
# ...

# %%
# create an empty Linear regression model
tv_model = LinearRegression()

# to create the model, we use fit(x,y)
tv_model.fit(x,y)

y_pred = tv_model.predict(x)
plt.scatter(x,y,color = 'b')
plt.plot(x,tv_model.predict(x), color = 'r')
plt.title('Sales v/s TV Budget')
plt.ylabel('Sales')
plt.xlabel('TV Budget')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Newspaper Simple Linear

# %%
x = data.iloc[:,2].values # Newspaper
print(x)
y = data.iloc[:,3].values # Sales
y=y.reshape(-1, 1)
x=x.reshape(-1, 1)
# Out:
# [ 69.2  45.1  69.3  58.5  58.4  75.   23.5  11.6   1.   21.2  24.2   4.
#   65.9   7.2  46.   52.9 114.   55.8  18.3  19.1  53.4  23.5  49.6  26.2
#   18.3  19.5  12.6  22.9  22.9  40.8  43.2  38.6  30.    0.3   7.4   8.5
#    5.   45.7  35.1  32.   31.6  38.7   1.8  26.4  43.3  31.5  35.7  18.5
#   49.9  36.8  34.6   3.6  39.6  58.7  15.9  60.   41.4  16.6  37.7   9.3
#   21.4  54.7  27.3   8.4  28.9   0.9   2.2  10.2  11.   27.2  38.7  31.7
#   19.3  31.3  13.1  89.4  20.7  14.2   9.4  23.1  22.3  36.9  32.5  35.6
#   33.8  65.7  16.   63.2  73.4  51.4   9.3  33.   59.   72.3  10.9  52.9
#    5.9  22.   51.2  45.9  49.8 100.9  21.4  17.9   5.3  59.   29.7  23.2
#   25.6   5.5  56.5  23.2   2.4  10.7  34.5  52.7  25.6  14.8  79.2  22.3
#   46.2  50.4  15.6  12.4  74.2  25.9  50.6   9.2   3.2  43.1   8.7  43.
#    2.1  45.1  65.6   8.5   9.3  59.7  20.5   1.7  12.9  75.6  37.9  34.4
#   38.9   9.    8.7  44.3  11.9  20.6  37.   48.7  14.2  37.7   9.5   5.7
# ...

# %%
# create an empty Linear regression model
newspaper_model = LinearRegression()

# to create the model, we use fit(x,y)
newspaper_model.fit(x,y)

y_pred = newspaper_model.predict(x)
plt.scatter(x,y,color = 'b')
plt.plot(x,newspaper_model.predict(x), color = 'r')
plt.title('Sales v/s Newspaper Budget')
plt.ylabel('Sales')
plt.xlabel('Newspaper Budget')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Coefficients: \n",newspaper_model.coef_)
# Out:
# Coefficients:
#  [[0.0546931]]

# %% [markdown]
# Multiple Linear Regression

# %%
X = data.iloc[:,[0,1,2]].values # All the rows, 3 types of Sales. Multiple columns.
X[1:4]
# Out:
# array([[ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5]])

# %%
y = data.iloc[:,3].values # Sales
y = y.reshape(-1,1)
X = X.reshape(-1,3) # You can also use lowercase x

# create an empty Linear regression model Like below and give it a good variable name
advertising_model = LinearRegression()

# to create the model, we use fit(x,y)
advertising_model.fit(X,y)

print('Intercept: \n', advertising_model.intercept_)
print('Coefficients: \n', advertising_model.coef_)
# Out:
# Intercept:
#  [2.93888937]
# Coefficients:
#  [[ 0.04576465  0.18853002 -0.00103749]]

# %% [markdown]
# Training and Test Samples

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, shuffle=True)

print ("Training data:",X_train.shape, y_train.shape) #Seen data. Observations, Number of columns.
print ("Test data:",X_test.shape, y_test.shape) # Unseen data. Observations, Number of columns.
# Out:
# Training data: (150, 3) (150, 1)
# Test data: (50, 3) (50, 1)

# %% [markdown]
# Using a 0.25 test size split our data of 200 items into a training set of 150 observations and three columns,
# and a test set of 50 observations.
#
# We can use this to evaluate our model.

# %% [markdown]
# Now we'll fit the model on the training data:

# %%
# fit a model
lm = LinearRegression()
# Fit model on training data
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

# %%
predictions[0:5] # 1 to # 4
# Out:
# array([[ 6.64186866],
#        [ 7.39925594],
#        [ 8.42920366],
#        [20.70223765],
#        [13.76736627]])

# %%
## Plot the errors
residuals = y_test-predictions # Y testing data minus our predictions
residuals = np.squeeze(residuals) # Squeeze it to 1D array

#ensure only +tive values are taken for yerr
res_absolute = np.abs(residuals)
res_absolute = np.squeeze(res_absolute)

# Why did this take me so Long to figure out?

# %%
plt.errorbar(range(1,51), np.squeeze(y_test), yerr=res_absolute, fmt='.k', ecolor="red") 
# We know our test data is 50 values long hence range(1,51)
# Squeeze to 1 D array
# Y-error calculation . We calculate the error value of the absolute residuals (res_absolute)
# format, .k
# Error colour , red
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# The red lines indicate the error of the prediction from the actual observations. (How fat off the predictions are from the observed values.)
#
# Sklearn's LinearRegression provides the R squared score for its models:

# %%
print ("Score:", model.score(X_test, y_test))
# Out:
# Score: 0.9179245473246376

# %% [markdown]
# This score is quite close to 1, which suggests that our model fits our observations quite well.
