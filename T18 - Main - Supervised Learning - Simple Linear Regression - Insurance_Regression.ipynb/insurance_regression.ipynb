# %%
import pandas as pd # For reading and preprocessing data for use in scikit-learn.
import numpy as np # Allows you to work with multidimensional arrays and matrices. It’s perfect for scientific or mathematical calculations.
import seaborn as sns # Essential for Data visualization.
import matplotlib.pyplot as plt # Essential for Data visualization.
from sklearn.linear_model import LinearRegression # Involves solving a system of linear equations
# %matplotlib inline

# %%
file_path = r"\Users\tailb\Data Science\JUPYTER NOTEBOOK\insurance.csv"
insurance_data = pd.read_csv(file_path,delim_whitespace="") # delim_whitespace=0
insurance_data.head()
# Out:
# C:\Users\tailb\AppData\Local\Temp\ipykernel_29928\3020617213.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   insurance_data = pd.read_csv(file_path,delim_whitespace="") # delim_whitespace=0
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#x = insurance_data.loc[:,"age"].values # All the rows, Column labeled age.
#y = insurance_data.loc[:,"charges"].values # All the rows, Column labeled charges.

# iloc() Purely integer-location based indexing for selection by position.
x = insurance_data.iloc[:,:1].values.round(0) # All the rows, Only 1st Column. Select Age Column
y = insurance_data.iloc[:,-1].values.round(0) # All rows, Last Column. Select charges Column

plt.scatter(x,y,color = 'c') # c is cyan colour
plt.xlabel("Age") # Independent Variable
plt.ylabel("Charges") # Dependent Variable
plt.show()

# %% [markdown]
# Fitting a Linear Regression Model.
# .fit() prepares the data for prediction.

# %%
# create an empty Linear regression model
insurance_model = LinearRegression()

# to create the model, we use fit(x,y)
insurance_model.fit(x,y) # iloc.() is recommended!
# Out:
# LinearRegression()

# %% [markdown]
# We want to make a prediction of the Y value based on whatever value X value we feed.
# The prediction values will be our ‘line of best fit’.

# %%
y_pred = insurance_model.predict(x)

plt.scatter(x,y,color = 'c') # c is cyan colour
plt.plot(x,y_pred,color = 'r') # Plots line of best fit.
plt.xlabel("Age") # Independent Variable
plt.ylabel("Charges") # Dependent Variable
plt.show()

# %%
#insurance_data[["region","charges"]].groupby("region").sum().round(0)
#insurance_data[["smoker","charges"]].groupby("smoker").sum().round(0)
#insurance_data[["sex","charges"]].groupby("sex").sum().round(0)
#insurance_data[["age","charges"]].groupby("age").mean().head()
#insurance_data[["age","charges"]].groupby("age").max().head()
#insurance_data[["age","charges"]].groupby("age").mean().head()
#insurance_data[["region","smoker","sex","charges"]].groupby(["region","smoker","sex"]).sum().round(0)
#charges_ascending = insurance_data.sort_values(by="charges",ascending=True)
#print(charges_ascending)
#insurance_data.loc[9,:] # Select row 9 and all corresponding data.
#insurance_data.loc[0:5] # Slice dataset from exactly line 0 to 5
#insurance_data.iloc[0:5] # Slice dataset from line 0 to 4
#insurance_data.iloc[:,[0,1,2]].head() # slice dataset including all rows, select column 1, column 2 and column 3.
